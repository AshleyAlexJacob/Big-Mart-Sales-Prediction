# %%
import pandas as pd
import os
import category_encoders as ce

# %%
os.chdir("../")

# %%
df = pd.read_csv("data/raw/train.csv")

# %% [markdown]
# ### Item Identifier

# %%
df['Item_Identifier']
# Out:
# 0       FDA15
# 1       DRC01
# 2       FDN15
# 3       FDX07
# 4       NCD19
#         ...
# 8518    FDF22
# 8519    FDS36
# 8520    NCJ29
# 8521    FDN46
# 8522    DRG01
# Name: Item_Identifier, Length: 8523, dtype: object

# %%
encoder = ce.TargetEncoder(cols=['Item_Identifier'])
df['Item_Identifier_encoded'] = encoder.fit_transform(df['Item_Identifier'], df['Item_Outlet_Sales'])

# %%
df['Item_Identifier_encoded'] = df['Item_Identifier_encoded'].astype('int')

# %%
df[['Item_Identifier', 'Item_Identifier_encoded']]
# Out:
#      Item_Identifier  Item_Identifier_encoded
# 0              FDA15                     2879
# 1              DRC01                     1920
# 2              FDN15                     2030
# 3              FDX07                     2347
# 4              NCD19                     1879
# ...              ...                      ...
# 8518           FDF22                     2424
# 8519           FDS36                     2271
# 8520           NCJ29                     1991
# 8521           FDN46                     2158
# 8522           DRG01                     2006
#
# [8523 rows x 2 columns]

# %% [markdown]
# ### Item Type

# %%
src_column = 'Item_Type'
target_column = f'{src_column}_encoded'
encoder = ce.TargetEncoder(cols=[src_column])
df[target_column] = encoder.fit_transform(df[src_column], df['Item_Outlet_Sales'])
df[target_column] = df[target_column].astype('int')
df[[src_column, target_column]]
# Out:
#                   Item_Type  Item_Type_encoded
# 0                     Dairy               2232
# 1               Soft Drinks               2006
# 2                      Meat               2158
# 3     Fruits and Vegetables               2289
# 4                 Household               2258
# ...                     ...                ...
# 8518            Snack Foods               2277
# 8519           Baking Goods               1952
# 8520     Health and Hygiene               2010
# 8521            Snack Foods               2277
# 8522            Soft Drinks               2006
#
# [8523 rows x 2 columns]

# %% [markdown]
# ### Item_Fat_Content

# %%
src_column = 'Item_Fat_Content'
target_column = f'{src_column}_encoded'
df[target_column] = df[src_column].map({
    'Low Fat': "LF",
    'Regular': "REG",
    'reg': "REG",
    'low fat': "LF"
})

df = pd.get_dummies(df, columns=[target_column], dtype=int)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales  Item_Identifier_encoded  \
# 0  Supermarket Type1          3735.1380                     2879
# 1  Supermarket Type2           443.4228                     1920
# 2  Supermarket Type1          2097.2700                     2030
# 3      Grocery Store           732.3800                     2347
# 4  Supermarket Type1           994.7052                     1879
#
#    Item_Type_encoded  Item_Fat_Content_encoded_LF  \
# 0               2232                         True
# 1               2006                        False
# 2               2158                         True
# 3               2289                        False
# 4               2258                         True
#
#    Item_Fat_Content_encoded_REG  Item_Fat_Content_encoded_LF  \
# 0                         False                            1
# 1                          True                            0
# 2                         False                            1
# 3                          True                            0
# 4                         False                            1
#
#    Item_Fat_Content_encoded_REG
# 0                             0
# 1                             1
# 2                             0
# 3                             1
# 4                             0

# %% [markdown]
# ### Outlet_Location_Type

# %%
src_column = 'Outlet_Location_Type'
df = pd.get_dummies(df, columns=[src_column], dtype=int)
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#          Outlet_Type  Item_Outlet_Sales  Item_Identifier_encoded  \
# 0  Supermarket Type1          3735.1380                     2879
# 1  Supermarket Type2           443.4228                     1920
#
#    Item_Type_encoded  Item_Fat_Content_encoded_LF  \
# 0               2232                         True
# 1               2006                        False
#
#    Item_Fat_Content_encoded_REG  Item_Fat_Content_encoded_LF  \
# 0                         False                            1
# 1                          True                            0
#
#    Item_Fat_Content_encoded_REG  Outlet_Location_Type_Tier 1  \
# 0                             0                            1
# 1                             1                            0
#
#    Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3
# 0                            0                            0
# 1                            0                            1

# %% [markdown]
# ### Outlet_Size

# %%
src_column = 'Outlet_Size'
df = pd.get_dummies(df, columns=[src_column], dtype=int)
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year        Outlet_Type  \
# 0  249.8092            OUT049                       1999  Supermarket Type1
# 1   48.2692            OUT018                       2009  Supermarket Type2
#
#    Item_Outlet_Sales  ...  Item_Fat_Content_encoded_LF  \
# 0          3735.1380  ...                         True
# 1           443.4228  ...                        False
#
#    Item_Fat_Content_encoded_REG  Item_Fat_Content_encoded_LF  \
# 0                         False                            1
# 1                          True                            0
#
#    Item_Fat_Content_encoded_REG  Outlet_Location_Type_Tier 1  \
# 0                             0                            1
# 1                             1                            0
#
#    Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3  Outlet_Size_High  \
# 0                            0                            0                 0
# 1                            0                            1                 0
#
#    Outlet_Size_Medium  Outlet_Size_Small
# 0                   1                  0
# 1                   1                  0
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Outlet_Type

# %%
src_column = 'Outlet_Type'
df = pd.get_dummies(df, columns=[src_column], dtype=int)
df.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales  \
# 0  249.8092            OUT049                       1999          3735.1380
# 1   48.2692            OUT018                       2009           443.4228
#
#    Item_Identifier_encoded  ...  Outlet_Location_Type_Tier 1  \
# 0                     2879  ...                            1
# 1                     1920  ...                            0
#
#    Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3  Outlet_Size_High  \
# 0                            0                            0                 0
# 1                            0                            1                 0
#
#    Outlet_Size_Medium  Outlet_Size_Small  Outlet_Type_Grocery Store  \
# 0                   1                  0                          0
# 1                   1                  0                          0
#
#    Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                              1                              0
# 1                              0                              1
#
#    Outlet_Type_Supermarket Type3
# 0                              0
# 1                              0
#
# [2 rows x 25 columns]
